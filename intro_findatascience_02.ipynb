# %% [markdown]
# # Introduction to Quant Platform|

# %% [markdown]
# ## The Very Basics

# %% [markdown]
# Here we can write general text.
#
# Write **bold text**.
#
# Write _italic text_.
#
# Write `fixed-width text`.

# %%
print('Hello Quants.')
# Out:
# Hello Quants.

# %% [markdown]
# It is easy to write Latex and render formulas:
#
# $$dS_t = rS_tdt + \sigma S_tdZ_t $$
#
# This is inline Latex $S_t$.

# %%
from IPython.display import Image

# %%
Image('http://hilpisch.com/tpq_logo.png')

# %% [markdown]
# <img src='http://hilpisch.com/tpq_logo.png'>

# %% [markdown]
# ## pandas Example

# %%
import pandas as pd

# %%
from pandas_datareader import data as web

# %%
AAPL = web.DataReader('AAPL', data_source='yahoo')

# %%
AAPL.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-08-23  108.589996  109.320000  108.529999  108.849998  21257700
# 2016-08-24  108.570000  108.750000  107.680000  108.029999  23675100
# 2016-08-25  107.389999  107.879997  106.680000  107.570000  25086200
# 2016-08-26  107.410004  107.949997  106.309998  106.940002  27766300
# 2016-08-29  106.620003  107.440002  106.290001  106.820000  24770200
#
#              Adj Close
# Date
# 2016-08-23  108.849998
# 2016-08-24  108.029999
# 2016-08-25  107.570000
# 2016-08-26  106.940002
# 2016-08-29  106.820000

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1676 entries, 2010-01-04 to 2016-08-29
# Data columns (total 6 columns):
# Open         1676 non-null float64
# High         1676 non-null float64
# Low          1676 non-null float64
# Close        1676 non-null float64
# Volume       1676 non-null int64
# Adj Close    1676 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 91.7 KB

# %%
# %matplotlib inline

# %%
import seaborn as sns; sns.set()

# %%
AAPL['100d'] = AAPL['Adj Close'].rolling(100).mean()

# %%
AAPL['Adj Close'].plot(figsize=(10, 6), grid=True, title='AAPL Adj Close');

# %%
AAPL[['Adj Close', '100d']].plot(figsize=(10, 6), grid=True, title='AAPL Adj Close');
